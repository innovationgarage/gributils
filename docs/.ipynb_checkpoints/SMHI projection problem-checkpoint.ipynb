# %%
# %pylab inline
import pygrib
from mpl_toolkits.basemap import Basemap
import os
import scipy.ndimage.interpolation
import pyproj
import shapely.geometry
import matplotlib.pyplot as plt 
from descartes import PolygonPatch
import descartes
import skimage.measure
import shapely.ops
import shapely.wkt
import functools
import cartopy
import cartopy.crs
import cartopy.io.img_tiles
import hashlib
import gributils.projection
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Bugfix from https://github.com/SciTools/cartopy/issues/1341
import six
from PIL import Image

def new_get_image(self, tile):
    if six.PY3:
        from urllib.request import urlopen, Request
    else:
        from urllib2 import urlopen
    url = self._image_url(tile)  # added by H.C. Winsemius
    req = Request(url) # added by H.C. Winsemius
    req.add_header('User-agent', 'your bot 0.1')
    # fh = urlopen(url)  # removed by H.C. Winsemius
    fh = urlopen(req)
    im_data = six.BytesIO(fh.read())
    fh.close()
    img = Image.open(im_data)
    img = img.convert(self.desired_tile_form)
    return img, self.tileextent(tile), 'lower'
cartopy.io.img_tiles.GoogleWTS.get_image = new_get_image

# %%
grbs = pygrib.open("../WeatherScrape/smhi/NS01_SURF_201809031800+000H00M.grib")
grb = grbs[12]

# %%
grb
# Out:
# 12:V-comp of Current:cm/s (instant):regular_ll:heightAboveGround:level 0:fcst time 0 hrs:from 201809031800

# %%
grb.projparams
# Out:
# {'a': 6367470, 'b': 6367470, 'proj': 'cyl'}

# %%
BLUE = '#6699cc'

fig = plt.figure(figsize=(20,20))
tiles = cartopy.io.img_tiles.OSM()
ax = plt.axes(projection=tiles.crs)
ax.set_extent([-10,40,50,70])
ax.add_image(tiles, 4)

wgs84 = cartopy.crs.Geodetic()
def tr(x, y):
    return tiles.crs.transform_point(x, y, wgs84)

# The old version of the GRIB file format has a limitation that makes pygrib make an
# accumulating rounding error when constructing the lat lon grid.
lats, lons = grb.latlons()
n = scipy.ndimage.morphology.binary_fill_holes(
        (grb.values >= grb.minimum) & (grb.values <= grb.maximum))
xys = tiles.crs.transform_points(wgs84, lons[n], lats[n])[:,:2]
ax.plot(xys[:,0], xys[:,1], ",r", alpha=0.3)

plt.show()

# %%
BLUE = '#6699cc'

fig = plt.figure(figsize=(20,20))
tiles = cartopy.io.img_tiles.OSM()
ax = plt.axes(projection=tiles.crs)
ax.set_extent([-10,40,50,70])
ax.add_image(tiles, 4)

wgs84 = cartopy.crs.Geodetic()
def tr(x, y):
    return tiles.crs.transform_point(x, y, wgs84)


# Calculate the lats and lons of the grid using gributils.projection
# to work around limitation
projection = gributils.projection.LayerProjection(grb)
lats, lons = projection.latlons()


n = scipy.ndimage.morphology.binary_fill_holes(
        (grb.values >= grb.minimum) & (grb.values <= grb.maximum))
xys = tiles.crs.transform_points(wgs84, lons[n], lats[n])[:,:2]
ax.plot(xys[:,0], xys[:,1], ",r", alpha=0.3)

plt.show()
